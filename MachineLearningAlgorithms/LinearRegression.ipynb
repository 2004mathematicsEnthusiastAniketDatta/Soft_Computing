# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
from sklearn.model_selection import train_test_split,cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error,r2_score
from sklearn import linear_model
from sklearn.linear_model import LinearRegression

# %%
df_sal=pd.read_csv('https://raw.githubusercontent.com//tmsllab//datasets//refs//heads//main//salary_data.csv')
df_sal.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
df_sal.describe()
# Out:
#        YearsExperience         Salary
# count        30.000000      30.000000
# mean          5.313333   76003.000000
# std           2.837888   27414.429785
# min           1.100000   37731.000000
# 25%           3.200000   56720.750000
# 50%           4.700000   65237.000000
# 75%           7.700000  100544.750000
# max          10.500000  122391.000000

# %%
df_sal.corr()
# Out:
#                  YearsExperience    Salary
# YearsExperience         1.000000  0.978242
# Salary                  0.978242  1.000000

# %%
plt.title("Salary  Distribution plot")
sb.distplot(df_sal['Salary'])
plt.show()
# Out:
# /tmp/ipykernel_6569/1723959300.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(df_sal['Salary'])

# %%
X=df_sal.iloc[:,:1]
Y=df_sal.iloc[:,1:]

# %%
plt.title("Salary vs Years of Experience")
plt.scatter(df_sal['YearsExperience'],df['Salary'],c='blue')
plt.xlabel("Years of Experience")
plt.ylabel("Salary")
# plt.grid()
plt.box(False)
plt.show()

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.20,random_state=42)
print(X_train)
print(X_test)
print(Y_train)
print(Y_test)
# Out:
#     YearsExperience
# 28             10.3
# 24              8.7
# 12              4.0
# 0               1.1
# 4               2.2
# 16              5.1
# 5               2.9
# 13              4.1
# 11              4.0
# 22              7.9
# 1               1.3
# 2               1.5
# 25              9.0
# 3               2.0
# 21              7.1
# 26              9.5
# 18              5.9
# 29             10.5
# 20              6.8
# 7               3.2
# 10              3.9
# 14              4.5
# 19              6.0
# 6               3.0
#     YearsExperience
# 27              9.6
# 15              4.9
# 23              8.2
# 17              5.3
# 8               3.2
# 9               3.7
#       Salary
# 28  122391.0
# 24  109431.0
# 12   56957.0
# 0    39343.0
# 4    39891.0
# 16   66029.0
# 5    56642.0
# 13   57081.0
# 11   55794.0
# 22  101302.0
# 1    46205.0
# 2    37731.0
# 25  105582.0
# 3    43525.0
# 21   98273.0
# 26  116969.0
# 18   81363.0
# 29  121872.0
# ...

# %%
Regression=LinearRegression()
Regression.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
y_pred_test=Regression.predict(X_test)
y_pred_train=Regression.predict(X_train)

# %%
plt.scatter(X_train,Y_train,color='green')
plt.plot(X_train,y_pred_train,color='blue')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.legend(['X_train/Pred(Y_train)','X_train,Y_train'],title='Sal/Exp',loc='best',facecolor='white')
plt.box(False)
plt.show()

# %%
mse=mean_squared_error(Y_test,y_pred_test)
mse
# Out:
# 49830096.85590839

# %%
r2_sc=r2_score(Y_test,y_pred_test)
r2_sc
# Out:
# 0.9024461774180497
